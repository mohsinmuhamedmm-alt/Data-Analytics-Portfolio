# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('customer_behaviour.csv', delimiter=';')
df
# Out:
#       account length  location code  user id credit card info save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push status  add to wishlist  desktop sessions  app sessions  \
# 0            yes               25               265            45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   account length                       3333 non-null   int64
#  1   location code                        3333 non-null   int64
#  2   user id                              3333 non-null   int64
#  3   credit card info save                3333 non-null   object
#  4   push status                          3333 non-null   object
#  5   add to wishlist                      3333 non-null   int64
#  6   desktop sessions                     3333 non-null   int64
#  7   app sessions                         3333 non-null   int64
#  8   desktop transactions                 3333 non-null   int64
#  9   total product detail views           3333 non-null   int64
#  10  session duration                     3333 non-null   int64
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df['avg_order_value'] = df['avg_order_value'].replace(',','.', regex=True,).astype(float)
df['discount_rate_per_visited_products'] = df['discount_rate_per_visited_products'].replace(',','.', regex=True,).astype(float)
df['product_detail_view_per_app_session'] = df['product_detail_view_per_app_session'].replace(',', '.', regex=True).astype(float)
df['add_to_cart_per_session'] = df['add_to_cart_per_session'].replace(',','.', regex=True,).astype(float)
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   account_length                       3333 non-null   int64
#  1   location_code                        3333 non-null   int64
#  2   user_id                              3333 non-null   int64
#  3   credit_card_info_save                3333 non-null   object
#  4   push_status                          3333 non-null   object
#  5   add_to_wishlist                      3333 non-null   int64
#  6   desktop_sessions                     3333 non-null   int64
#  7   app_sessions                         3333 non-null   int64
#  8   desktop_transactions                 3333 non-null   int64
#  9   total_product_detail_views           3333 non-null   int64
#  10  session_duration                     3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        account_length  location_code       user_id  add_to_wishlist  \
# count     3333.000000    3333.000000  3.333000e+03      3333.000000
# mean       101.064806     437.182418  3.746291e+06         8.099010
# std         39.822106      42.371290  2.746626e+05        13.688365
# min          1.000000     408.000000  3.271058e+06         0.000000
# 25%         74.000000     408.000000  3.508680e+06         0.000000
# 50%        101.000000     415.000000  3.748187e+06         0.000000
# 75%        127.000000     510.000000  3.985970e+06        20.000000
# max        243.000000     510.000000  4.229964e+06        51.000000
#
#        desktop_sessions  app_sessions  desktop_transactions  \
# count       3333.000000   3333.000000           3333.000000
# mean         179.811881     30.567957             17.087609
# std           54.457135      9.269376              4.323795
# min            0.000000      0.000000              0.000000
# ...

# %%
df.describe(exclude=['int', 'float'])
# Out:
#        credit_card_info_save push_status
# count                   3333        3333
# unique                     2           2
# top                       no          no
# freq                    3010        2411

# %%
df.columns
# Out:
# Index(['account_length', 'location_code', 'user_id', 'credit_card_info_save',
#        'push_status', 'add_to_wishlist', 'desktop_sessions', 'app_sessions',
#        'desktop_transactions', 'total_product_detail_views',
#        'session_duration', 'promotion_clicks', 'avg_order_value',
#        'sale_product_views', 'discount_rate_per_visited_products',
#        'product_detail_view_per_app_session', 'app_transactions',
#        'add_to_cart_per_session', 'customer_service_calls', 'churn'],
#       dtype='object')

# %%
numeric_columns = ['account_length','add_to_wishlist', 'desktop_sessions', 
                   'app_sessions','desktop_transactions',
                   'total_product_detail_views','session_duration', 'promotion_clicks',
                   'avg_order_value','sale_product_views', 
                   'discount_rate_per_visited_products',
                   'product_detail_view_per_app_session', 'app_transactions',
                   'add_to_cart_per_session', 'customer_service_calls']

fig, axes = plt.subplots(5,3, figsize=(24,24))
fig.suptitle('Distribution of numeric variables', size=48)

for i in range(5):
    for j in range(3):
        sns.histplot(df[numeric_columns[3*i+j]], ax=axes[i,j])

# %%
df.churn.value_counts()
# Out:
# churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))

plt.pie(df.churn.value_counts(), labels = ['Not churn', 'churn'], autopct='%.0f%%')

cp = sns.countplot(x=df['churn'], ax=ax[0], palette = 'husl')
cp.set_xlabel('Churn', fontsize=14)
cp.set_ylabel('Number of customers', fontsize=14)

plt.show()
# Out:
# /var/folders/cr/wjvb_x0n2xjdtpg_vhz62xp40000gn/T/ipykernel_55677/1267950988.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   cp = sns.countplot(x=df['churn'], ax=ax[0], palette = 'husl')

# %%
df['account_length_months'] = (df['account_length'] / 30).round(1)

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   account_length                       3333 non-null   int64
#  1   location_code                        3333 non-null   int64
#  2   user_id                              3333 non-null   int64
#  3   credit_card_info_save                3333 non-null   object
#  4   push_status                          3333 non-null   object
#  5   add_to_wishlist                      3333 non-null   int64
#  6   desktop_sessions                     3333 non-null   int64
#  7   app_sessions                         3333 non-null   int64
#  8   desktop_transactions                 3333 non-null   int64
#  9   total_product_detail_views           3333 non-null   int64
#  10  session_duration                     3333 non-null   int64
# ...

# %%
df['churn'] = df['churn'].replace({0:'No', 1:'Yes'})

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df['session_duration'] = df['session_duration'] / 60

# %%
df['session_duration'].astype(int)
# Out:
# 0       6
# 1       6
# 2       4
# 3       2
# 4       4
#        ..
# 3328    7
# 3329    5
# 3330    9
# 3331    5
# 3332    8
# Name: session_duration, Length: 3333, dtype: int64

# %%
df = df.rename(columns={'session_duration': 'session_duration_min'})
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df['session_duration_min'].astype(int)
# Out:
# 0       6
# 1       6
# 2       4
# 3       2
# 4       4
#        ..
# 3328    7
# 3329    5
# 3330    9
# 3331    5
# 3332    8
# Name: session_duration_min, Length: 3333, dtype: int64

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df2 = ['account_length', 'location_code', 'credit_card_info_save','desktop_transactions', 'total_product_detail_views','session_duration_min','avg_order_value','product_detail_view_per_app_session', 'app_transactions','add_to_cart_per_session', 'customer_service_calls', 'churn','account_length_months']
frame = df[df2]
frame
# Out:
#       account_length  location_code credit_card_info_save  \
# 0                128            415                    no
# 1                107            415                    no
# 2                137            415                    no
# 3                 84            408                   yes
# 4                 75            415                   yes
# ...              ...            ...                   ...
# 3328             192            415                    no
# 3329              68            415                    no
# 3330              28            510                    no
# 3331             184            510                   yes
# 3332              74            415                    no
#
#       desktop_transactions  total_product_detail_views  session_duration_min  \
# 0                       17                         110              6.566667
# 1                       17                         123              6.533333
# ...

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   account_length                       3333 non-null   int64
#  1   location_code                        3333 non-null   int64
#  2   credit_card_info_save                3333 non-null   object
#  3   desktop_transactions                 3333 non-null   int64
#  4   total_product_detail_views           3333 non-null   int64
#  5   session_duration_min                 3333 non-null   float64
#  6   avg_order_value                      3333 non-null   float64
#  7   product_detail_view_per_app_session  3333 non-null   float64
#  8   app_transactions                     3333 non-null   int64
#  9   add_to_cart_per_session              3333 non-null   float64
#  10  customer_service_calls               3333 non-null   int64
# ...

# %%
frame['session_duration_min'].astype(int)
# Out:
# 0       6
# 1       6
# 2       4
# 3       2
# 4       4
#        ..
# 3328    7
# 3329    5
# 3330    9
# 3331    5
# 3332    8
# Name: session_duration_min, Length: 3333, dtype: int64

# %%
df['total_transactions'] = df['desktop_transactions'] + df['app_transactions']
df['total_sessions'] = df['desktop_sessions'] + df['app_sessions']
df['conversion_rate'] = df['total_transactions'] / df['total_sessions']

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df['tenure_group'] = pd.cut(df['account_length_months'], 
                            bins=[0,3,6,12,24,6], labels=['0 - 3m', '3-6m', '1-2y', '2y+'])

# %%
df
# Out:
#       account_length  location_code  user_id credit_card_info_save  \
# 0                128            415  3824657                    no
# 1                107            415  3717191                    no
# 2                137            415  3581921                    no
# 3                 84            408  3759999                   yes
# 4                 75            415  3306626                   yes
# ...              ...            ...      ...                   ...
# 3328             192            415  4144276                    no
# 3329              68            415  3703271                    no
# 3330              28            510  3288230                    no
# 3331             184            510  3646381                   yes
# 3332              74            415  4004344                    no
#
#      push_status  add_to_wishlist  desktop_sessions  app_sessions  \
# 0            yes               25               265            45
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('tableau_customer.csv', index=False)
